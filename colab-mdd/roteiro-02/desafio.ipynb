# %%
DESAFIO - ACIDENTE TOP 2

# %%
acidente_top2 = df[df['id'] == 745267]
acidente_top2

# %%
acidente_top2 ['pesid'].nunique()

# %%
acidente_top2 ['causa_acidente'].unique()

# %%
pessoas_unicas_m2 = acidente_top2[acidente_top2['mortos'] == 1]
pessoas_unicas_m2

# %%
pessoas_unicas_m2.value_counts('pesid')

# %%
DESAFIO - ACIDENTE TOP 3

# %%
acidente_top3 = df[df['id'] == 691021]
acidente_top3

# %%
acidente_top3 ['pesid'].nunique()

# %%
acidente_top3 ['causa_acidente'].unique()

# %%
pessoas_unicas_m3 = acidente_top3[acidente_top3['mortos'] == 1]
pessoas_unicas_m3

# %%
pessoas_unicas_m3.value_counts('pesid')
